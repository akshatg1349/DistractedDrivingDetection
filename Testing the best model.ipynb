# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # YOLOv10

# %%
import os
# Define paths
data_yaml = '/content/drive/MyDrive/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/data.yaml'
best_model_path = "/content/drive/MyDrive/1:1_Akshat_Gupta/Models/yolo10_best_model_epoch_40_lr_0.0005/yolo10s_custom/weights/best.pt"  # Replace with your best model path

# %%
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.0 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

model = YOLO(best_model_path)

# Run evaluation on the test set to calculate mAP50
results = model.val(data=data_yaml, split='test', conf=0.5, iou=0.5)

# Print the mAP50 score
# print(f"mAP50: {results['metrics/mAP_0.5']}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv10s summary (fused): 106 layers, 7,221,096 parameters, 0 gradients, 21.4 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.9±0.5 ms, read: 9.4±20.6 MB/s, size: 70.1 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1KWZYqS8DRi6TnfSpgN_gQ_SJdaJ_Uqpn/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/test/labels.cache... 137 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 137/137 20.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.4it/s 2.7s
# ...

# %%
import shutil

shutil.move('/content/runs/detect/val', '/content/drive/MyDrive/1:1_Akshat_Gupta/Results/test__images_yolo10')
# Out:
# '/content/drive/MyDrive/1:1_Akshat_Gupta/Results/test__images_yolo10'
