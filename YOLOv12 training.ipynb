# %%
! pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.5 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# set the data yaml file path
data_yaml = "/content/drive/MyDrive/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/data.yaml"

# %%
# define the number of epochs and learning rate
EPOCHS = 30
LEARNING_RATE = 0.00001
#LEARNING_RATE = 0.0005
#LEARNING_RATE = 0.001
#LEARNING_RATE = 0.005
#LEARNING_RATE = 0.01

! yolo task=detect mode=train model=yolo12s.pt data={data_yaml} optimizer="Adam" epochs={EPOCHS} imgsz=640 lr0={LEARNING_RATE} name=yolo12s_custom
# Out:
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo12s_custom, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/yolo12s_custom, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 4]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1    345856  ultralytics.nn.modules.block.A2C2f           [768, 256, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     95104  ultralytics.nn.modules.block.A2C2f           [512, 128, 1, False, -1]
#  15                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1    296704  ultralytics.nn.modules.block.A2C2f           [384, 256, 1, False, -1]
#  18                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  21        [14, 17, 20]  1    822504  ultralytics.nn.modules.head.Detect           [8, 16, None, [128, 256, 512]]
# YOLOv12s summary: 272 layers, 9,256,232 parameters, 9,256,216 gradients, 21.5 GFLOPs
#
# Transferred 685/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.5±0.1 ms, read: 53.7±28.1 MB/s, size: 91.0 KB)
# train: Scanning /content/drive/.shortcut-targets-by-id/1KWZYqS8DRi6TnfSpgN_gQ_SJdaJ_Uqpn/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/train/labels.cache... 1105 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1105/1105 154.5Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 1.0±0.2 ms, read: 15.0±6.1 MB/s, size: 43.9 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1KWZYqS8DRi6TnfSpgN_gQ_SJdaJ_Uqpn/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/valid/labels.cache... 138 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 138/138 8.5Mit/s 0.0s
# optimizer: Adam(lr=0.0005, momentum=0.937) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Plotting labels to /content/runs/detect/yolo12s_custom/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/runs/detect/yolo12s_custom
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      5.99G     0.9959       2.75       1.53          3        640: 100% ━━━━━━━━━━━━ 70/70 2.4it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1s/it 5.5s
#                    all        138        138      0.217      0.741      0.371      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      6.58G     0.9291      1.686       1.43          1        640: 100% ━━━━━━━━━━━━ 70/70 6.6it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.3it/s 0.6s
#                    all        138        138      0.607      0.659      0.578      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      6.58G     0.8817      1.514      1.374          2        640: 100% ━━━━━━━━━━━━ 70/70 6.8it/s 10.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.7it/s 0.6s
#                    all        138        138      0.762      0.648      0.741      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      6.58G     0.8838       1.44      1.386          2        640: 100% ━━━━━━━━━━━━ 70/70 6.7it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.5it/s 0.6s
#                    all        138        138      0.569      0.685      0.716      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      6.58G     0.8366      1.322      1.361          2        640: 100% ━━━━━━━━━━━━ 70/70 6.8it/s 10.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.5it/s 0.6s
#                    all        138        138      0.835      0.818      0.896      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      6.58G     0.8086      1.266       1.32          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.7it/s 0.6s
#                    all        138        138      0.701      0.742      0.832      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      6.58G     0.8142      1.294      1.328          4        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.0it/s 0.6s
#                    all        138        138      0.842      0.834       0.93      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      6.58G     0.7553      1.155      1.293          2        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s
#                    all        138        138      0.783      0.872      0.905      0.773
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      6.58G     0.7911      1.165      1.339          1        640: 100% ━━━━━━━━━━━━ 70/70 6.8it/s 10.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.1it/s 0.6s
#                    all        138        138      0.807      0.866        0.9       0.76
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      6.58G     0.7156      1.094      1.251          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.8it/s 0.6s
#                    all        138        138      0.827      0.916      0.938      0.807
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      6.58G     0.7251      1.077      1.272          4        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.0it/s 0.6s
#                    all        138        138      0.905      0.921       0.95      0.812
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      6.58G     0.7257      1.035      1.264          4        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.5it/s 0.6s
#                    all        138        138      0.903      0.899      0.955       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      6.58G     0.6925      1.003      1.241          2        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.2it/s 0.5s
#                    all        138        138      0.946       0.95      0.971      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      6.58G     0.6659     0.9663      1.224          1        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s
#                    all        138        138      0.937      0.928      0.969      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      6.58G     0.6748     0.9729      1.219          3        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.0it/s 0.6s
#                    all        138        138      0.934      0.912      0.966      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      6.58G     0.6715     0.8913       1.22          3        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.6it/s 0.6s
#                    all        138        138      0.919      0.916      0.963      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      6.58G     0.6504     0.8957      1.203          3        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.7it/s 0.6s
#                    all        138        138       0.91      0.923      0.972      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      6.58G     0.6779     0.9041      1.237          1        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.3it/s 0.6s
#                    all        138        138      0.871      0.931      0.944      0.836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      6.58G     0.6388     0.8488      1.196          4        640: 100% ━━━━━━━━━━━━ 70/70 6.8it/s 10.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.9it/s 0.6s
#                    all        138        138      0.942      0.919      0.963      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      6.58G     0.6449     0.8619      1.206          4        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.7it/s 0.6s
#                    all        138        138      0.918      0.941      0.955      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      6.58G     0.6141      0.832      1.182          4        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.9it/s 0.6s
#                    all        138        138      0.942      0.935      0.965      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      6.58G     0.5893     0.8187      1.164          4        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s
#                    all        138        138      0.945      0.914      0.961      0.871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      6.58G     0.5972     0.8121      1.169          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.3it/s 0.6s
#                    all        138        138      0.903      0.948      0.973      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      6.58G     0.6037     0.7756      1.169          4        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.5it/s 0.6s
#                    all        138        138      0.881      0.929       0.96      0.871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      6.58G     0.5883     0.7939      1.169          1        640: 100% ━━━━━━━━━━━━ 70/70 7.2it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.6it/s 0.6s
#                    all        138        138       0.96       0.92      0.978      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      6.58G     0.5882     0.7665       1.16          4        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.4it/s 0.6s
#                    all        138        138      0.929      0.939      0.969      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      6.58G     0.5669     0.7477       1.15          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.4it/s 0.6s
#                    all        138        138      0.929      0.947      0.974      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      6.58G     0.5708     0.7548      1.158          3        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.7it/s 0.6s
#                    all        138        138       0.95       0.96      0.979       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      6.58G     0.5592     0.7293      1.139          3        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.0it/s 0.6s
#                    all        138        138      0.916      0.976      0.972      0.885
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      6.58G     0.5546     0.6848      1.133          4        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.0it/s 0.6s
#                    all        138        138      0.962      0.944      0.976      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      6.58G     0.5429     0.6797      1.134          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.9it/s 0.6s
#                    all        138        138      0.942      0.969      0.974      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      6.58G      0.559     0.7252      1.141          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.7it/s 0.6s
#                    all        138        138      0.901      0.933      0.941      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      6.58G     0.5195     0.6444      1.106          4        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.0it/s 0.6s
#                    all        138        138      0.943      0.942      0.971      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      6.58G     0.5171     0.6635      1.121          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.0it/s 0.6s
#                    all        138        138      0.953      0.942      0.982      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      6.58G     0.5268     0.6507      1.115          4        640: 100% ━━━━━━━━━━━━ 70/70 6.8it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.3it/s 0.6s
#                    all        138        138      0.949      0.965      0.975      0.904
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      6.58G     0.5005     0.6607      1.097          2        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.7it/s 0.6s
#                    all        138        138      0.947      0.969       0.98      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      6.58G     0.4938     0.6133      1.098          4        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.6it/s 0.6s
#                    all        138        138      0.966      0.956      0.976      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      6.58G      0.465     0.5974      1.074          3        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.9it/s 0.6s
#                    all        138        138      0.969      0.956      0.984      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      6.58G     0.4803     0.6089      1.096          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.9it/s 0.6s
#                    all        138        138      0.941      0.963      0.979      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      6.58G     0.4706     0.5863      1.082          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.9it/s 0.6s
#                    all        138        138       0.97      0.974       0.98      0.927
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      6.58G     0.3639     0.2654      1.039          1        640: 100% ━━━━━━━━━━━━ 70/70 6.4it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.0it/s 0.6s
#                    all        138        138      0.951      0.959      0.969      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      6.58G     0.3525     0.2452       1.05          1        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.1it/s 0.6s
#                    all        138        138      0.953      0.946      0.971      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      6.58G     0.3317     0.2242      1.024          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.3it/s 0.5s
#                    all        138        138      0.967      0.961      0.969      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      6.58G     0.3234     0.2205     0.9937          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.1it/s 0.5s
#                    all        138        138       0.96      0.964      0.974      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      6.58G     0.3126     0.2042      1.001          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.0it/s 0.6s
#                    all        138        138       0.96      0.959      0.971       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      6.58G     0.3037     0.1957     0.9889          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s
#                    all        138        138      0.968      0.957      0.974      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      6.58G     0.2954     0.1909     0.9855          1        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.7it/s 0.6s
#                    all        138        138      0.973      0.969      0.979      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      6.58G     0.2925     0.1827     0.9696          1        640: 100% ━━━━━━━━━━━━ 70/70 7.2it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.6it/s 0.6s
#                    all        138        138      0.972      0.969      0.983      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      6.58G     0.2861     0.1931     0.9553          1        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.6it/s 0.6s
#                    all        138        138      0.971      0.969      0.971      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      6.58G     0.2831     0.1766      0.968          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.2it/s 0.5s
#                    all        138        138      0.971      0.968      0.974      0.928
#
# 50 epochs completed in 0.164 hours.
# Optimizer stripped from /content/runs/detect/yolo12s_custom/weights/last.pt, 18.9MB
# Optimizer stripped from /content/runs/detect/yolo12s_custom/weights/best.pt, 18.9MB
#
# Validating /content/runs/detect/yolo12s_custom/weights/best.pt...
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv12s summary (fused): 159 layers, 9,233,976 parameters, 0 gradients, 21.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.9it/s 1.3s
#                    all        138        138      0.973      0.969      0.979      0.932
#               drinking         22         22      0.997      0.955       0.99      0.921
#        hair and makeup         13         13          1      0.928      0.995      0.936
#    operating the radio         18         18      0.997          1      0.995      0.995
#        reaching behind         16         16      0.999          1      0.995      0.934
#           safe driving         15         15      0.967      0.867       0.93      0.841
#   talking on the phone         19         19      0.944          1      0.977      0.936
#   talking to passenger          8          8      0.882          1      0.954      0.917
#                texting         27         27      0.997          1      0.995      0.979
# Speed: 0.1ms preprocess, 1.1ms inference, 0.0ms loss, 3.8ms postprocess per image
# Results saved to /content/runs/detect/yolo12s_custom
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
import shutil
import os

def create_directory(directory_path):
    # Check if the directory exists
    if not os.path.exists(directory_path):
        # If it doesn't exist, create it
        os.makedirs(directory_path)
        print(f"Directory '{directory_path}' created.")
    else:
        print(f"Directory '{directory_path}' already exists.")

# %%
# Specify the directory path you want to check/create
model_name = f'yolo12_best_model_epoch_{EPOCHS}_lr_{LEARNING_RATE}'
model_folder = '/content/drive/MyDrive/1:1_Akshat_Gupta/Models'
destination_path = os.path.join(model_folder, model_name)

# Call the function to check and create the directory
create_directory(destination_path)

# IMPORTANT
# define the best model custom data path
source_path = '/content/runs/detect/yolo12s_custom'
shutil.move(source_path, destination_path)
# Out:
# Directory '/content/drive/MyDrive/1:1_Akshat_Gupta/Models/yolo12_best_model_epoch_50_lr_0.0005' created.
# '/content/drive/MyDrive/1:1_Akshat_Gupta/Models/yolo12_best_model_epoch_50_lr_0.0005/yolo12s_custom'
