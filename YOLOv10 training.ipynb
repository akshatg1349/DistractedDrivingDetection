# %%
! pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.3 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# set the data yaml file path
data_yaml = "/content/drive/MyDrive/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/data.yaml"

# %%
# define the number of epochs and learning rate
EPOCHS = 30
#LEARNING_RATE = 0.00001
#LEARNING_RATE = 0.0005
LEARNING_RATE = 0.001
#LEARNING_RATE = 0.005
#LEARNING_RATE = 0.01

! yolo task=detect mode=train model=yolov10s.pt data={data_yaml} optimizer="Adam" epochs={EPOCHS} imgsz=640 lr0={LEARNING_RATE} name=yolo10s_custom
# Out:
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov10s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo10s_custom, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/yolo10s_custom, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1     36096  ultralytics.nn.modules.block.SCDown          [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1    137728  ultralytics.nn.modules.block.SCDown          [256, 512, 3, 2]
#   8                  -1  1    958464  ultralytics.nn.modules.block.C2fCIB          [512, 512, 1, True, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.PSA             [512, 512]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  20                  -1  1     68864  ultralytics.nn.modules.block.SCDown          [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1089536  ultralytics.nn.modules.block.C2fCIB          [768, 512, 1, True, True]
#  23        [16, 19, 22]  1   1644992  ultralytics.nn.modules.head.v10Detect        [8, [128, 256, 512]]
# YOLOv10s summary: 235 layers, 8,072,544 parameters, 8,072,528 gradients, 24.8 GFLOPs
#
# Transferred 607/619 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.4±0.1 ms, read: 50.8±23.2 MB/s, size: 91.0 KB)
# train: Scanning /content/drive/.shortcut-targets-by-id/1KWZYqS8DRi6TnfSpgN_gQ_SJdaJ_Uqpn/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/train/labels.cache... 1105 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1105/1105 165.5Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 14.4±28.9 ms, read: 9.1±6.4 MB/s, size: 43.9 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1KWZYqS8DRi6TnfSpgN_gQ_SJdaJ_Uqpn/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/valid/labels.cache... 138 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 138/138 5.0Mit/s 0.0s
# optimizer: Adam(lr=0.005, momentum=0.937) with parameter groups 99 weight(decay=0.0), 112 weight(decay=0.0005), 111 bias(decay=0.0)
# Plotting labels to /content/runs/detect/yolo10s_custom/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/runs/detect/yolo10s_custom
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      4.83G      1.296      4.849      1.784          3        640: 100% ━━━━━━━━━━━━ 70/70 2.3it/s 30.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.4s/it 7.0s
#                    all        138        138          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      5.42G       1.41      2.472      1.785          1        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.1it/s 0.5s
#                    all        138        138          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      5.42G      1.386      2.252      1.733          2        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 13.6it/s 0.4s
#                    all        138        138          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      5.42G      1.289      2.132      1.678          2        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.0it/s 0.5s
#                    all        138        138     0.0937     0.0605     0.0691     0.0367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      5.42G       1.22      2.038      1.626          2        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.4it/s 0.5s
#                    all        138        138      0.132      0.239      0.109     0.0472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      5.42G      1.191      1.948      1.585          2        640: 100% ━━━━━━━━━━━━ 70/70 7.2it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.3it/s 0.5s
#                    all        138        138      0.412      0.469      0.266      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.42G      1.211      1.895      1.583          4        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138      0.339      0.673      0.285      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      5.42G      1.149      1.901      1.552          2        640: 100% ━━━━━━━━━━━━ 70/70 7.5it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.4it/s 0.5s
#                    all        138        138      0.186      0.647      0.254      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      5.42G      1.096      1.843      1.518          1        640: 100% ━━━━━━━━━━━━ 70/70 7.2it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.3it/s 0.5s
#                    all        138        138      0.154      0.553      0.249       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.42G       1.04      1.833      1.477          2        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.3it/s 0.5s
#                    all        138        138       0.22       0.65      0.344      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      5.42G      1.054      1.764      1.481          4        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.1it/s 0.5s
#                    all        138        138      0.264      0.746      0.378      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      5.42G      1.074      1.718      1.487          4        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.6it/s 0.5s
#                    all        138        138      0.244      0.693        0.4      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      5.42G      1.022      1.663      1.452          2        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.4it/s 0.5s
#                    all        138        138      0.243      0.707      0.393      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      5.42G     0.9758      1.598      1.423          1        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.9it/s 0.5s
#                    all        138        138      0.386      0.622      0.525      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      5.42G     0.9649      1.583      1.393          3        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.9it/s 0.5s
#                    all        138        138      0.393      0.728      0.509      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      5.42G     0.9765      1.538       1.41          3        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.0it/s 0.5s
#                    all        138        138      0.362      0.693      0.512      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      5.42G     0.9648      1.529      1.398          3        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.2it/s 0.5s
#                    all        138        138      0.405      0.752      0.562      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      5.42G     0.9607      1.514      1.433          1        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138      0.404      0.693      0.547      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      5.42G     0.9485      1.506      1.387          4        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138      0.425      0.742      0.563      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      5.42G     0.9241      1.463       1.39          4        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138      0.467      0.747       0.61      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      5.42G     0.8972      1.444      1.354          4        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.1it/s 0.5s
#                    all        138        138      0.467      0.693      0.605      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      5.42G     0.8719      1.366      1.332          4        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.7it/s 0.5s
#                    all        138        138      0.548      0.687      0.708      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      5.42G     0.8624      1.367      1.339          2        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.1it/s 0.5s
#                    all        138        138      0.584      0.756      0.685      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      5.42G     0.8414      1.302      1.307          4        640: 100% ━━━━━━━━━━━━ 70/70 7.2it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.6it/s 0.6s
#                    all        138        138      0.577      0.786      0.761      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      5.42G     0.8539      1.287      1.332          1        640: 100% ━━━━━━━━━━━━ 70/70 7.5it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.9it/s 0.5s
#                    all        138        138      0.637      0.822      0.802      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      5.42G     0.8408      1.284      1.312          4        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.2it/s 0.5s
#                    all        138        138      0.667       0.83      0.814      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      5.42G     0.8159      1.259      1.305          2        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.7it/s 0.5s
#                    all        138        138       0.66        0.9       0.77      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      5.42G     0.8133       1.23      1.303          3        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.3it/s 0.5s
#                    all        138        138      0.675       0.89      0.785       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      5.42G     0.7968      1.209      1.284          3        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.6it/s 0.5s
#                    all        138        138       0.77      0.663      0.779      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      5.42G     0.7806      1.149      1.261          4        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.3it/s 0.5s
#                    all        138        138      0.769      0.923      0.891      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      5.42G     0.7679      1.109      1.267          1        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.4it/s 0.5s
#                    all        138        138      0.804      0.824      0.893      0.779
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      5.42G     0.7616      1.129      1.258          1        640: 100% ━━━━━━━━━━━━ 70/70 7.6it/s 9.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.2it/s 0.5s
#                    all        138        138      0.841      0.854      0.903      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      5.42G      0.734       1.06      1.231          4        640: 100% ━━━━━━━━━━━━ 70/70 7.2it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.6it/s 0.5s
#                    all        138        138      0.705       0.89      0.853      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      5.42G     0.7437      1.066      1.256          2        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138       0.81      0.818      0.898      0.803
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      5.42G     0.7505      1.037      1.254          4        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.4it/s 0.5s
#                    all        138        138      0.837      0.805      0.916      0.824
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      5.42G      0.715      1.083      1.222          2        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138      0.801      0.857      0.907      0.808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      5.42G     0.7055     0.9898      1.223          4        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.6it/s 0.5s
#                    all        138        138      0.873      0.808      0.921      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      5.42G      0.694     0.9681      1.199          3        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138      0.903      0.872       0.96      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      5.42G     0.6928       0.99      1.231          2        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.0it/s 0.5s
#                    all        138        138      0.857      0.891      0.931      0.837
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      5.42G     0.6739     0.9622      1.206          2        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.2it/s 0.5s
#                    all        138        138      0.905      0.867      0.944      0.851
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      5.42G     0.5551     0.5586      1.233          1        640: 100% ━━━━━━━━━━━━ 70/70 6.4it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.3it/s 0.5s
#                    all        138        138      0.879      0.906      0.952       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      5.42G     0.5027     0.5058      1.199          1        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.3it/s 0.5s
#                    all        138        138      0.881      0.909      0.947      0.864
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      5.42G     0.4761     0.4059      1.167          1        640: 100% ━━━━━━━━━━━━ 70/70 7.3it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.3it/s 0.5s
#                    all        138        138      0.935      0.921       0.96      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      5.42G     0.4608     0.3774      1.122          1        640: 100% ━━━━━━━━━━━━ 70/70 7.5it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.9it/s 0.5s
#                    all        138        138      0.941      0.924      0.963      0.878
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.42G     0.4616     0.3805      1.145          1        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.7it/s 0.5s
#                    all        138        138      0.916      0.917      0.969      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.42G     0.4443     0.3516      1.115          1        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.3it/s 0.5s
#                    all        138        138      0.925      0.894      0.961      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.42G     0.4286     0.3225      1.112          1        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.4it/s 0.5s
#                    all        138        138      0.947      0.901      0.975      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.42G     0.4241      0.309       1.09          1        640: 100% ━━━━━━━━━━━━ 70/70 7.5it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.6it/s 0.5s
#                    all        138        138      0.937      0.942      0.967      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.42G     0.4129        0.3      1.083          1        640: 100% ━━━━━━━━━━━━ 70/70 7.5it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.5it/s 0.5s
#                    all        138        138      0.929       0.93      0.962      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.42G     0.4122     0.2883      1.091          1        640: 100% ━━━━━━━━━━━━ 70/70 7.4it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.3it/s 0.5s
#                    all        138        138      0.931      0.942      0.968      0.892
#
# 50 epochs completed in 0.157 hours.
# Optimizer stripped from /content/runs/detect/yolo10s_custom/weights/last.pt, 16.5MB
# Optimizer stripped from /content/runs/detect/yolo10s_custom/weights/best.pt, 16.5MB
#
# Validating /content/runs/detect/yolo10s_custom/weights/best.pt...
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv10s summary (fused): 106 layers, 7,221,096 parameters, 0 gradients, 21.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.2it/s 1.2s
#                    all        138        138      0.931      0.942      0.969      0.893
#               drinking         22         22      0.977      0.955      0.974      0.905
#        hair and makeup         13         13      0.842      0.923      0.942      0.864
#    operating the radio         18         18      0.988          1      0.995      0.955
#        reaching behind         16         16      0.995          1      0.995      0.878
#           safe driving         15         15      0.842      0.711       0.92      0.789
#   talking on the phone         19         19      0.996      0.947      0.988       0.94
#   talking to passenger          8          8      0.838          1      0.939      0.872
#                texting         27         27      0.972          1      0.995       0.94
# Speed: 0.1ms preprocess, 1.3ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /content/runs/detect/yolo10s_custom
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
import shutil
import os

def create_directory(directory_path):
    # Check if the directory exists
    if not os.path.exists(directory_path):
        # If it doesn't exist, create it
        os.makedirs(directory_path)
        print(f"Directory '{directory_path}' created.")
    else:
        print(f"Directory '{directory_path}' already exists.")

# %%
# Specify the directory path you want to check/create
model_name = f'yolo10_best_model_epoch_{EPOCHS}_lr_{LEARNING_RATE}'
model_folder = '/content/drive/MyDrive/1:1_Akshat_Gupta/Models'
destination_path = os.path.join(model_folder, model_name)

# Call the function to check and create the directory
create_directory(destination_path)

# IMPORTANT
# define the best model custom data path
source_path = '/content/runs/detect/yolo10s_custom'
shutil.move(source_path, destination_path)
# Out:
# Directory '/content/drive/MyDrive/1:1_Akshat_Gupta/Models/yolo10_best_model_epoch_50_lr_0.005' created.
# '/content/drive/MyDrive/1:1_Akshat_Gupta/Models/yolo10_best_model_epoch_50_lr_0.005/yolo10s_custom'

# %%
ls /content/runs/detect/
