# %%
! pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.3 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# set the data yaml file path
data_yaml = "/content/drive/MyDrive/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/data.yaml"

# %%
# define the number of epochs and learning rate
EPOCHS = 40
#LEARNING_RATE = 0.00001
#LEARNING_RATE = 0.0005
#LEARNING_RATE = 0.001
#LEARNING_RATE = 0.005
LEARNING_RATE = 0.01

! yolo task=detect mode=train model=rtdetr-l.pt data={data_yaml} optimizer="Adam" epochs={EPOCHS} imgsz=640 lr0={LEARNING_RATE} name=rtdetr_l_custom
# Out:
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %%
import shutil
import os

def create_directory(directory_path):
    # Check if the directory exists
    if not os.path.exists(directory_path):
        # If it doesn't exist, create it
        os.makedirs(directory_path)
        print(f"Directory '{directory_path}' created.")
    else:
        print(f"Directory '{directory_path}' already exists.")

# %%
# Specify the directory path you want to check/create
model_name = f'rtdetr_best_model_epoch_{EPOCHS}_lr_{LEARNING_RATE}'
model_folder = '/content/drive/MyDrive/1:1_Akshat_Gupta/Models'
destination_path = os.path.join(model_folder, model_name)

# Call the function to check and create the directory
create_directory(destination_path)

# IMPORTANT
# define the best model custom data path
source_path = '/content/runs/detect/rtdetr_l_custom'
shutil.move(source_path, destination_path)
# Out:
# Directory '/content/drive/MyDrive/1:1_Akshat_Gupta/Models/rtdetr_best_model_epoch_40_lr_0.01' created.
# '/content/drive/MyDrive/1:1_Akshat_Gupta/Models/rtdetr_best_model_epoch_40_lr_0.01/rtdetr_l_custom'

# %%
ls /content/runs/detect/
