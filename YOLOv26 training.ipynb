# %%
! pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.9 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# set the data yaml file path
data_yaml = "/content/drive/MyDrive/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/data.yaml"

# %%
# define the number of epochs and learning rate
EPOCHS = 30
#LEARNING_RATE = 0.00001
#LEARNING_RATE = 0.0005
#LEARNING_RATE = 0.001
LEARNING_RATE = 0.005
#LEARNING_RATE = 0.01

! yolo task=detect mode=train model=yolo26s.pt data={data_yaml} optimizer="Adam" epochs={EPOCHS} imgsz=640 lr0={LEARNING_RATE} name=yolo26s_custom
# Out:
# New https://pypi.org/project/ultralytics/8.4.72 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo26s_custom, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/yolo26s_custom, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    477184  ultralytics.nn.modules.block.C3k2            [768, 256, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    136192  ultralytics.nn.modules.block.C3k2            [512, 128, 1, True]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1843712  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    938056  ultralytics.nn.modules.head.Detect           [8, 1, True, [128, 256, 512]]
# YOLO26s summary: 260 layers, 9,954,056 parameters, 9,954,056 gradients, 22.5 GFLOPs
#
# Transferred 696/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.6±0.2 ms, read: 37.2±19.0 MB/s, size: 91.0 KB)
# train: Scanning /content/drive/.shortcut-targets-by-id/1KWZYqS8DRi6TnfSpgN_gQ_SJdaJ_Uqpn/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/train/labels.cache... 1105 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1105/1105 171.7Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 69.3±152.5 ms, read: 11.8±12.5 MB/s, size: 43.9 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1KWZYqS8DRi6TnfSpgN_gQ_SJdaJ_Uqpn/1:1_Akshat_Gupta/Datasets/Distracted-Driving-1/valid/labels.cache... 138 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 138/138 5.2Mit/s 0.0s
# optimizer: Adam(lr=0.01, momentum=0.937) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /content/runs/detect/yolo26s_custom/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/runs/detect/yolo26s_custom
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      4.71G       1.61      4.191    0.04145          3        640: 100% ━━━━━━━━━━━━ 70/70 2.3it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.3s/it 6.3s
#                    all        138        138          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50       5.3G      1.705      2.676    0.04501          1        640: 100% ━━━━━━━━━━━━ 70/70 6.6it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.3it/s 0.5s
#                    all        138        138    0.00613      0.317    0.00388   0.000923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50       5.3G      1.695        2.3    0.04321          2        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.8it/s 0.5s
#                    all        138        138     0.0711      0.414     0.0903      0.037
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50       5.3G      1.699      2.234    0.04433          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.2it/s 0.5s
#                    all        138        138     0.0704      0.534     0.0881     0.0302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50       5.3G      1.607      2.151    0.04242          2        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.6it/s 0.5s
#                    all        138        138      0.327      0.491      0.127     0.0314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50       5.3G      1.532      2.044    0.03914          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.4it/s 0.5s
#                    all        138        138      0.101      0.756      0.146     0.0524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50       5.3G      1.538      2.039    0.03971          4        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.4it/s 0.5s
#                    all        138        138      0.125      0.575      0.148     0.0918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50       5.3G      1.484      1.989    0.03841          2        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.0it/s 0.5s
#                    all        138        138      0.111      0.505      0.152     0.0889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50       5.3G      1.407      1.999    0.03605          1        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.1it/s 0.5s
#                    all        138        138      0.118      0.714      0.174     0.0849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50       5.3G      1.377      1.946    0.03493          2        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138      0.122      0.361      0.149     0.0598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50       5.3G      1.338      1.893    0.03399          4        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.2it/s 0.5s
#                    all        138        138      0.148      0.614      0.173     0.0929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50       5.3G      1.368      1.916    0.03442          4        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138      0.153      0.677      0.252      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50       5.3G      1.366      1.899     0.0348          2        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.4it/s 0.5s
#                    all        138        138      0.143      0.551      0.203      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50       5.3G      1.306      1.842    0.03296          1        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.7it/s 0.5s
#                    all        138        138      0.171      0.701      0.253      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50       5.3G      1.249      1.821    0.03063          3        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.2it/s 0.5s
#                    all        138        138      0.381      0.496      0.292       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50       5.3G      1.287      1.779    0.03239          3        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.2it/s 0.5s
#                    all        138        138      0.228      0.792      0.298      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50       5.3G       1.25      1.773    0.03093          3        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.5it/s 0.5s
#                    all        138        138      0.168      0.739       0.28      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50       5.3G      1.248      1.776    0.03185          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.5it/s 0.5s
#                    all        138        138      0.217      0.672       0.33       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50       5.3G      1.233      1.752    0.03069          4        640: 100% ━━━━━━━━━━━━ 70/70 6.7it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.3it/s 0.5s
#                    all        138        138      0.266      0.715      0.387       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50       5.3G       1.18      1.681    0.02977          4        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138      0.225        0.7      0.423      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50       5.3G      1.137      1.709    0.02792          4        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.3it/s 0.5s
#                    all        138        138      0.368      0.709      0.426      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50       5.3G      1.161      1.677    0.02892          4        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.0it/s 0.5s
#                    all        138        138      0.322      0.783      0.389      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50       5.3G      1.161      1.637     0.0292          2        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.1it/s 0.5s
#                    all        138        138      0.368      0.574      0.402      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50       5.3G      1.137      1.609    0.02758          4        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.7it/s 0.5s
#                    all        138        138      0.282      0.654      0.449      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50       5.3G      1.125      1.583    0.02796          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.0it/s 0.6s
#                    all        138        138      0.317      0.715      0.435      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50       5.3G      1.104      1.583    0.02726          4        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.0it/s 0.5s
#                    all        138        138      0.305      0.606      0.436      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50       5.3G        1.1      1.576    0.02762          2        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.0it/s 0.5s
#                    all        138        138       0.41      0.679      0.595      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50       5.3G      1.075      1.546    0.02613          3        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138       0.26      0.753      0.411      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50       5.3G      1.107      1.565    0.02717          3        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.9it/s 0.5s
#                    all        138        138      0.316      0.542      0.427      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50       5.3G      1.076       1.51    0.02607          4        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.4it/s 0.5s
#                    all        138        138      0.418      0.691      0.591      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50       5.3G      1.018       1.45    0.02536          1        640: 100% ━━━━━━━━━━━━ 70/70 6.8it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.3it/s 0.5s
#                    all        138        138      0.723      0.653      0.725       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50       5.3G      1.018      1.448    0.02537          1        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.2it/s 0.5s
#                    all        138        138      0.407      0.683       0.47      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50       5.3G     0.9948      1.401    0.02414          4        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.2it/s 0.5s
#                    all        138        138      0.595      0.696      0.693      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50       5.3G       0.97      1.368    0.02426          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.4it/s 0.5s
#                    all        138        138       0.42      0.728      0.606      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50       5.3G     0.9772      1.341    0.02356          4        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.2it/s 0.5s
#                    all        138        138      0.407      0.639      0.619      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50       5.3G     0.9741      1.373    0.02328          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.4it/s 0.5s
#                    all        138        138      0.573      0.741      0.747      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50       5.3G     0.9779       1.29    0.02391          4        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.5it/s 0.5s
#                    all        138        138      0.679      0.725      0.769      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50       5.3G     0.9768      1.254     0.0236          3        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.5it/s 0.5s
#                    all        138        138      0.674      0.759      0.799      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50       5.3G     0.9464      1.284    0.02385          2        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.1it/s 0.5s
#                    all        138        138      0.595      0.729      0.764      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50       5.3G     0.8995      1.217     0.0217          2        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.4it/s 0.5s
#                    all        138        138      0.647      0.763      0.779      0.638
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50       5.3G     0.8664     0.8715    0.03242          1        640: 100% ━━━━━━━━━━━━ 70/70 6.2it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s
#                    all        138        138      0.608      0.789      0.761      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50       5.3G     0.8062     0.8248    0.03014          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.0it/s 0.5s
#                    all        138        138      0.666      0.788      0.808      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50       5.3G     0.7265     0.7672    0.02656          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.5it/s 0.5s
#                    all        138        138      0.666      0.886      0.838      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50       5.3G     0.7378     0.6849    0.02624          1        640: 100% ━━━━━━━━━━━━ 70/70 6.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.3it/s 0.5s
#                    all        138        138      0.769      0.926      0.849      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50       5.3G     0.6857     0.6552    0.02454          1        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.9it/s 0.5s
#                    all        138        138      0.721      0.927      0.863      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50       5.3G     0.6911     0.6461    0.02471          1        640: 100% ━━━━━━━━━━━━ 70/70 7.2it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.1it/s 0.5s
#                    all        138        138      0.845      0.791      0.885      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50       5.3G     0.6475     0.5722    0.02366          1        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.6it/s 0.5s
#                    all        138        138      0.757      0.932      0.892      0.742
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50       5.3G     0.6561      0.556    0.02351          1        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.9it/s 0.5s
#                    all        138        138      0.843      0.847      0.913      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50       5.3G     0.6128     0.5926    0.02159          1        640: 100% ━━━━━━━━━━━━ 70/70 7.0it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.3it/s 0.5s
#                    all        138        138      0.822      0.862      0.894       0.77
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50       5.3G     0.6149       0.51    0.02172          1        640: 100% ━━━━━━━━━━━━ 70/70 7.1it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.4it/s 0.5s
#                    all        138        138      0.863      0.813      0.894      0.758
#
# 50 epochs completed in 0.164 hours.
# Optimizer stripped from /content/runs/detect/yolo26s_custom/weights/last.pt, 20.3MB
# Optimizer stripped from /content/runs/detect/yolo26s_custom/weights/best.pt, 20.3MB
#
# Validating /content/runs/detect/yolo26s_custom/weights/best.pt...
# Ultralytics 8.4.71 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLO26s summary (fused): 122 layers, 9,468,276 parameters, 0 gradients, 20.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.4it/s 1.1s
#                    all        138        138      0.838       0.85      0.911      0.782
#               drinking         22         22      0.968      0.955      0.989      0.848
#        hair and makeup         13         13      0.796      0.923      0.941      0.775
#    operating the radio         18         18      0.806      0.924      0.936       0.81
#        reaching behind         16         16      0.829          1      0.995      0.812
#           safe driving         15         15      0.603      0.667      0.741      0.586
#   talking on the phone         19         19      0.916      0.895      0.985      0.901
#   talking to passenger          8          8      0.784      0.459      0.709       0.64
#                texting         27         27          1      0.976      0.995      0.883
# Speed: 0.1ms preprocess, 0.9ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to /content/runs/detect/yolo26s_custom
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
import shutil
import os

def create_directory(directory_path):
    # Check if the directory exists
    if not os.path.exists(directory_path):
        # If it doesn't exist, create it
        os.makedirs(directory_path)
        print(f"Directory '{directory_path}' created.")
    else:
        print(f"Directory '{directory_path}' already exists.")

# %%
# Specify the directory path you want to check/create
model_name = f'yolo26_best_model_epoch_{EPOCHS}_lr_{LEARNING_RATE}'
model_folder = '/content/drive/MyDrive/1:1_Akshat_Gupta/Models'
destination_path = os.path.join(model_folder, model_name)

# Call the function to check and create the directory
create_directory(destination_path)

# IMPORTANT
# define the best model custom data path
source_path = '/content/runs/detect/yolo26s_custom'
shutil.move(source_path, destination_path)
# Out:
# Directory '/content/drive/MyDrive/1:1_Akshat_Gupta/Models/yolo26_best_model_epoch_50_lr_0.01' created.
# '/content/drive/MyDrive/1:1_Akshat_Gupta/Models/yolo26_best_model_epoch_50_lr_0.01/yolo26s_custom'
